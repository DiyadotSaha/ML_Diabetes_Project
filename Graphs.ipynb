# %% [markdown]
# ### MLP on the model with feature selection and only selecting the features that were commonly rated the highest importance by XGBoost, Adaboost and randomforest

# %%
'''
PERFORMANCE OF MLP ON COMMON FEATURE DATASET
Epoch 1/10
2227/2227 [==============================] - 1s 432us/step - loss: 0.9256 - accuracy: 0.5665 - val_loss: 0.9059 - val_accuracy: 0.5775
Epoch 2/10
2227/2227 [==============================] - 1s 403us/step - loss: 0.9039 - accuracy: 0.5730 - val_loss: 0.9000 - val_accuracy: 0.5727
Epoch 3/10
2227/2227 [==============================] - 1s 397us/step - loss: 0.8989 - accuracy: 0.5750 - val_loss: 0.8952 - val_accuracy: 0.5773
Epoch 4/10
2227/2227 [==============================] - 1s 395us/step - loss: 0.8961 - accuracy: 0.5761 - val_loss: 0.8956 - val_accuracy: 0.5817
Epoch 5/10
2227/2227 [==============================] - 1s 391us/step - loss: 0.8948 - accuracy: 0.5772 - val_loss: 0.8926 - val_accuracy: 0.5777
Epoch 6/10
2227/2227 [==============================] - 1s 383us/step - loss: 0.8941 - accuracy: 0.5765 - val_loss: 0.8974 - val_accuracy: 0.5750
Epoch 7/10
2227/2227 [==============================] - 1s 385us/step - loss: 0.8926 - accuracy: 0.5779 - val_loss: 0.8943 - val_accuracy: 0.5739
Epoch 8/10
2227/2227 [==============================] - 1s 389us/step - loss: 0.8926 - accuracy: 0.5782 - val_loss: 0.8966 - val_accuracy: 0.5761
Epoch 9/10
2227/2227 [==============================] - 1s 418us/step - loss: 0.8912 - accuracy: 0.5791 - val_loss: 0.8899 - val_accuracy: 0.5773
Epoch 10/10
2227/2227 [==============================] - 1s 398us/step - loss: 0.8903 - accuracy: 0.5782 - val_loss: 0.8903 - val_accuracy: 0.5774
315/315 [==============================] - 0s 212us/step

'''
import matplotlib.pyplot as plt

# Hardcoded accuracy values
epochs = list(range(1, 11))  # Assuming 10 epochs based on the provided output
train_accuracy = [0.5665, 0.5730, 0.5750, 0.5761, 0.5772, 0.5765, 0.5779, 0.5782, 0.5791, 0.5782]
validation_accuracy = [0.5775, 0.5727, 0.5773, 0.5817, 0.5777, 0.5750, 0.5739, 0.5761, 0.5773, 0.5774]

# Plotting the accuracy graph
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o')
plt.plot(epochs, validation_accuracy, label='Validation Accuracy', marker='o')
plt.title('MLP common best feature from XGBoost, Adaboost and Random Forest')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### MLP on the model with feature selection and only selecting the features that were combined rated the highest importance by XGBoost, Adaboost and randomforest

# %%
'''
Epoch 1/10
2227/2227 [==============================] - 1s 432us/step - loss: 0.9320 - accuracy: 0.5577 - val_loss: 0.9099 - val_accuracy: 0.5811
Epoch 2/10
2227/2227 [==============================] - 1s 404us/step - loss: 0.9028 - accuracy: 0.5732 - val_loss: 0.8991 - val_accuracy: 0.5704
Epoch 3/10
2227/2227 [==============================] - 1s 392us/step - loss: 0.8974 - accuracy: 0.5762 - val_loss: 0.8952 - val_accuracy: 0.5833
Epoch 4/10
2227/2227 [==============================] - 1s 391us/step - loss: 0.8931 - accuracy: 0.5774 - val_loss: 0.8949 - val_accuracy: 0.5761
Epoch 5/10
2227/2227 [==============================] - 1s 394us/step - loss: 0.8891 - accuracy: 0.5784 - val_loss: 0.8838 - val_accuracy: 0.5814
Epoch 6/10
2227/2227 [==============================] - 1s 390us/step - loss: 0.8860 - accuracy: 0.5801 - val_loss: 0.8817 - val_accuracy: 0.5821
Epoch 7/10
2227/2227 [==============================] - 1s 393us/step - loss: 0.8842 - accuracy: 0.5815 - val_loss: 0.8843 - val_accuracy: 0.5826
Epoch 8/10
2227/2227 [==============================] - 1s 423us/step - loss: 0.8823 - accuracy: 0.5813 - val_loss: 0.8833 - val_accuracy: 0.5833
Epoch 9/10
2227/2227 [==============================] - 1s 404us/step - loss: 0.8811 - accuracy: 0.5820 - val_loss: 0.8788 - val_accuracy: 0.5847
Epoch 10/10
2227/2227 [==============================] - 1s 402us/step - loss: 0.8793 - accuracy: 0.5831 - val_loss: 0.8813 - val_accuracy: 0.5839
315/315 [==============================] - 0s 229us/step

'''
import matplotlib.pyplot as plt

# Hardcoded accuracy values
epochs = list(range(1, 11))  # Assuming 10 epochs based on the provided output
train_accuracy = [0.5577, 0.5732, 0.5762, 0.5774, 0.5784, 0.5801, 0.5815, 0.5813, 0.5820, 0.5831]
val_accuracy = [0.5811, 0.5704, 0.5833, 0.5761, 0.5814, 0.5821, 0.5826, 0.5833, 0.5847, 0.5839]

# Plotting the accuracy graph
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', marker='o')
plt.title('MLP Combined best feature from XGBoost, Adaboost and Random Forest')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Class distributions
classes = ['No', '<30', '>30']
counts_original = [38439, 7922, 24875]
counts_ENN = [8495, 7922, 1661]
counts_SMOTE = [8495, 7922, 1661]
counts_SMOTEEN = [6189, 13615, 8320]

bar_width = 0.35  # Adjust the width as needed

# Plotting the class distributions
plt.figure(figsize=(7, 6))

plt.subplot(2, 2, 1)
plt.bar(classes, counts_original, color='blue', width=bar_width)
plt.title('Original Dataset')
plt.xlabel('Class')
plt.ylabel('Count')

plt.subplot(2, 2, 2)
plt.bar(classes, counts_ENN, color='green', width=bar_width)
plt.title('ENN')
plt.xlabel('Class')
plt.ylabel('Count')

plt.subplot(2, 2, 3)
plt.bar(classes, counts_SMOTE, color='orange', width=bar_width)
plt.title('SMOTE')
plt.xlabel('Class')
plt.ylabel('Count')

plt.subplot(2, 2, 4)
plt.bar(classes, counts_SMOTEEN, color='red', width=bar_width)
plt.title('SMOTE-ENN')
plt.xlabel('Class')
plt.ylabel('Count')

plt.tight_layout()
plt.show()
