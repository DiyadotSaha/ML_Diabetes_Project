# %%
pip install shap
# Out:
# Collecting shap
#   Obtaining dependency information for shap from https://files.pythonhosted.org/packages/55/d5/0a1c65b13ab5a24178d162d0cfd3f8a709588388cc5bdd32b17c119f6d54/shap-0.44.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading shap-0.44.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (24 kB)
# Requirement already satisfied: numpy in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (1.24.3)
# Requirement already satisfied: scipy in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (1.11.1)
# Requirement already satisfied: scikit-learn in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (1.3.0)
# Requirement already satisfied: pandas in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (2.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (23.1)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (0.57.1)
# Requirement already satisfied: cloudpickle in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from numba->shap) (0.40.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.44.0-cp311-cp311-macosx_11_0_arm64.whl (445 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.0/446.0 kB 10.7 MB/s eta 0:00:0000:01
# Installing collected packages: slicer, shap
# Successfully installed shap-0.44.0 slicer-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/76/e8/260752c1bc8dc856b27cfefaa3fca29ba02a15f649bbf6e9c15ed54e5480/xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl.metadata
#   Downloading xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in /Users/abhinandganesh/anaconda3/lib/python3.11/site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing packages
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests                                      # reading data
from io import StringIO

from sklearn.datasets import fetch_openml            # common data set access
from sklearn.preprocessing import StandardScaler     # scaling transform
from sklearn.model_selection import train_test_split # validation tools
from sklearn.metrics import zero_one_loss as J01
from sklearn.preprocessing import OneHotEncoder
import xgboost
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

import sklearn.tree as tree

# Fix the random seed for reproducibility
# !! Important !! : do not change this
seed = 1234
np.random.seed(seed)

# %%
# Reading in the CSV file
Xtr = pd.read_csv("data/X_TRAINING_SET_Diabetes_ENCODED.csv")
Ytr = pd.read_csv("data/Y_TRAINING_SET.csv")
Xtr = Xtr.drop(columns=['Unnamed: 0'])
                 
Xtest = pd.read_csv("data/X_VALIDATION_SET_ENCODED.csv")
Ytest = pd.read_csv("data/Y_VALIDATION_SET.csv")
Xtest = Xtest.drop(columns=['Unnamed: 0'])

# %%
Ytr['readmitted'] = Ytr['readmitted'].map({'<30': 1, 'NO': 0, '>30': 2})
Ytr.to_csv('data/Y_TRAINING_SET_EDIT.csv', index=False)
Ytest['readmitted'] = Ytest ['readmitted'].map({'<30': 1, 'NO': 0, '>30': 2})
Ytest.to_csv('data/Y_VALIDATION_SET_EDIT.csv', index=False)

# %%
cls = RandomForestClassifier(random_state=0)

cls.fit(Xtr, Ytr)

# %%
importances = cls.feature_importances_
indices = np.argsort(importances)[::-1]  # Reverse the order to get descending importance
features = Xtr.columns

n = 5  # You can change this to the desired number of features
top_n_indices = indices[:n]
top_n_features = [features[i] for i in top_n_indices]
top_n_importances = importances[top_n_indices]

print(f'Top {n} Features:')
for feature, importance in zip(top_n_features, top_n_importances):
    print(f'{feature}: {importance:.4f}')

# Plot the bar chart
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
# Out:
# Top 5 Features:
# number_inpatient: 0.1452
# number_outpatient: 0.0861
# patient_nbr: 0.0855
# number_emergency: 0.0852
# number_diagnoses: 0.0815

# %%
n = 25  # You can change this to the desired number of features
top_n_indices = indices[:n]
top_n_features = [features[i] for i in top_n_indices]
top_n_importances = importances[top_n_indices]

print(f'Top {n} Features:')
for feature, importance in zip(top_n_features, top_n_importances):
    print(f'{feature}: {importance:.4f}')
# Out:
# Top 25 Features:
# number_inpatient: 0.1452
# number_outpatient: 0.0861
# patient_nbr: 0.0855
# number_emergency: 0.0852
# number_diagnoses: 0.0815
# discharge_disposition_id: 0.0628
# index: 0.0614
# encounter_id: 0.0483
# num_medications: 0.0360
# num_procedures: 0.0310
# diabetesMed_No: 0.0293
# admission_source_id: 0.0272
# time_in_hospital: 0.0242
# diabetesMed_Yes: 0.0224
# payer_code_BC: 0.0224
# insulin_Down: 0.0216
# insulin_Up: 0.0172
# medical_specialty_ObstetricsandGynecology: 0.0150
# change_No: 0.0135
# weight_[75-100): 0.0102
# age_[70-80): 0.0075
# medical_specialty_Orthopedics: 0.0066
# metformin_Steady: 0.0064
# change_Ch: 0.0058
# num_lab_procedures: 0.0054

# %%
# Plot the bar chart for the top n importances
plt.title(f'Top {n} Feature Importances')
plt.barh(range(len(top_n_indices)), top_n_importances, color='g', align='center')
plt.yticks(range(len(top_n_indices)), [features[i] for i in top_n_indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# Select only the top n features in Xtr
Xtr_top_n = Xtr[top_n_features]

# %%
# compute SHAP values
explainer = shap.TreeExplainer(cls)
shap_values = explainer.shap_values(Xtr_top_n)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[21], line 3
#       1 # compute SHAP values
#       2 explainer = shap.TreeExplainer(cls)
# ----> 3 shap_values = explainer.shap_values(Xtr_top_n)
#
# File ~\anaconda3\Lib\site-packages\shap\explainers\_tree.py:427, in TreeExplainer.shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     425 # run the core algorithm using the C extension
#     426 assert_import("cext")
# --> 427 phi = np.zeros((X.shape[0], X.shape[1]+1, self.model.num_outputs))
#     428 if not approximate:
#     429     _cext.dense_tree_shap(
#     430         self.model.children_left, self.model.children_right, self.model.children_default,
#     431         self.model.features, self.model.thresholds, self.model.values, self.model.node_sample_weight,
#    (...)
#     434         output_transform_codes[transform], False
#     435     )
#
# MemoryError: Unable to allocate 1.92 TiB for an array with shape (71236, 26, 142472) and data type float64
